# %% [markdown]
# # Installation and study of Tensorflow

# %%
import tensorflow as tf

# %%
node1=tf.constant(3.0)
node2=tf.constant(4.0)
print(node1,node2)
# Out:
# tf.Tensor(3.0, shape=(), dtype=float32) tf.Tensor(4.0, shape=(), dtype=float32)

# %%
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
with tf.compat.v1.Session() as sess:
    a=tf.constant(3,name="input_a")
    b=tf.constant(4,name="input_b")
    c=tf.add(a,b,name="Result")
    writer=tf.compat.v1.summary.FileWriter("./logs",sess.graph)
    print(sess.run(c))
    sess.close()
    writer.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 10
#       8 writer = tf.summary.create_file_writer("./logs")
#       9 with writer.as_default():
# ---> 10     tf.summary.graph(simple_add.get_concrete_function().graph, step=0)
#      12 print(simple_add())
#
# TypeError: graph() got an unexpected keyword argument 'step'

# %%
# %tensorboard --logdir ./logs
# Out:
# Reusing TensorBoard on port 6006 (pid 10020), started 0:05:40 ago. (Use '!kill 10020' to kill it.)
#       <iframe id="tensorboard-frame-8ed6a4b7ec402588" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-8ed6a4b7ec402588");
#           const url = new URL("http://localhost");
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
