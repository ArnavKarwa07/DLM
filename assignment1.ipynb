# %% [markdown]
# # Installation and study of Tensorflow

# %%
import tensorflow as tf
# Out:
# c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
node1=tf.constant(3.0)
node2=tf.constant(4.0)
print(node1,node2)
# Out:
# tf.Tensor(3.0, shape=(), dtype=float32) tf.Tensor(4.0, shape=(), dtype=float32)

# %%
# %load_ext tensorboard

# %%
with tf.compat.v1.Session() as sess:
    a=tf.constant(3,name="input_a")
    b=tf.constant(4,name="input_b")
    c=tf.add(a,b,name="Result")
    writer=tf.compat.v1.summary.FileWriter("./logs",sess.graph)
    print(sess.run(c))
    sess.close()
    writer.close()
# Out:
# WARNING:tensorflow:From C:\Users\user\AppData\Local\Temp\ipykernel_20028\2006839186.py:1: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From C:\Users\user\AppData\Local\Temp\ipykernel_20028\2006839186.py:5: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# 7

# %%
# %tensorboard --logdir ./logs
# Out:
#       <iframe id="tensorboard-frame-903261e44da8c1c4" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-903261e44da8c1c4");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
